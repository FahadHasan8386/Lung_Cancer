# %% [markdown]
# <a href="https://colab.research.google.com/github/FahadHasan8386/Lung_Cancer/blob/main/Lung_Cancer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import VotingClassifier

# %%
data = pd.read_csv("/content/survey lung cancer.csv")

from sklearn import preprocessing
le = preprocessing.LabelEncoder()

# %%
data
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        M   69        1               2        2              1
# 1        M   74        2               1        1              1
# 2        F   59        1               1        1              2
# 3        M   63        2               2        2              1
# 4        F   63        1               2        1              1
# ..     ...  ...      ...             ...      ...            ...
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# 1                  2         2         2         1                  1
# 2                  1         2         1         2                  1
# 3                  1         1         1         1                  2
# 4                  1         1         1         2                  1
# ..               ...       ...       ...       ...                ...
# 304                2         2         1         1                  2
# 305                1         2         2         2                  2
# 306                1         1         2         2                  2
# 307                1         2         2         1                  2
# 308                1         2         2         2                  2
#
#      COUGHING  SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN  \
# 0           2                    2                      2           2
# 1           1                    2                      2           2
# 2           2                    2                      1           2
# 3           1                    1                      2           2
# 4           2                    2                      1           1
# ..        ...                  ...                    ...         ...
# 304         2                    2                      2           1
# 305         2                    2                      1           2
# 306         2                    1                      1           2
# 307         2                    2                      1           2
# 308         1                    1                      2           1
#
#     LUNG_CANCER
# 0           YES
# 1           YES
# 2            NO
# 3            NO
# 4            NO
# ..          ...
# 304         YES
# 305         YES
# 306         YES
# 307         YES
# 308         YES
#
# [309 rows x 16 columns]

# %%
x = data.drop(['LUNG_CANCER'], axis=1)
y = data.LUNG_CANCER
y
# Out:
# 0      YES
# 1      YES
# 2       NO
# 3       NO
# 4       NO
#       ...
# 304    YES
# 305    YES
# 306    YES
# 307    YES
# 308    YES
# Name: LUNG_CANCER, Length: 309, dtype: object

# %%
y = le.fit_transform(y)
x['GENDER'] = le.fit_transform(x['GENDER'])
x
# Out:
#      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0         1   69        1               2        2              1
# 1         1   74        2               1        1              1
# 2         0   59        1               1        1              2
# 3         1   63        2               2        2              1
# 4         0   63        1               2        1              1
# ..      ...  ...      ...             ...      ...            ...
# 304       0   56        1               1        1              2
# 305       1   70        2               1        1              1
# 306       1   58        2               1        1              1
# 307       1   67        2               1        2              1
# 308       1   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# 1                  2         2         2         1                  1
# 2                  1         2         1         2                  1
# 3                  1         1         1         1                  2
# 4                  1         1         1         2                  1
# ..               ...       ...       ...       ...                ...
# 304                2         2         1         1                  2
# 305                1         2         2         2                  2
# 306                1         1         2         2                  2
# 307                1         2         2         1                  2
# 308                1         2         2         2                  2
#
#      COUGHING  SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN
# 0           2                    2                      2           2
# 1           1                    2                      2           2
# 2           2                    2                      1           2
# 3           1                    1                      2           2
# 4           2                    2                      1           1
# ..        ...                  ...                    ...         ...
# 304         2                    2                      2           1
# 305         2                    2                      1           2
# 306         2                    1                      1           2
# 307         2                    2                      1           2
# 308         1                    1                      2           1
#
# [309 rows x 15 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25 )

# %%
from sklearn.naive_bayes import GaussianNB
NB_model = GaussianNB()
NB_classifier = NB_model.fit(x_train, y_train)
NB_prediction = NB_classifier.predict(x_test)
from sklearn.metrics import classification_report, confusion_matrix
CM = confusion_matrix(y_test, NB_prediction)
print("confusion matrix:\n", CM)
CR=classification_report(y_test, NB_prediction)
print("performance: \n", CR)
from sklearn.metrics import roc_curve, auc
y_prob = NB_model.predict_proba(x_test)[:,1]
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(false_positive_rate, true_positive_rate)
roc_auc
# Out:
# confusion matrix:
#  [[ 3  2]
#  [ 2 71]]
# performance:
#                precision    recall  f1-score   support
#
#            0       0.60      0.60      0.60         5
#            1       0.97      0.97      0.97        73
#
#     accuracy                           0.95        78
#    macro avg       0.79      0.79      0.79        78
# weighted avg       0.95      0.95      0.95        78
# np.float64(0.9452054794520548)

# %%
plt.figure(figsize=(10,10))
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate,true_positive_rate, color='red',label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],linestyle='--')
plt.axis('tight')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
# Out:
# Text(0.5, 0, 'False Positive Rate')

# %%
from sklearn.ensemble import RandomForestClassifier
NB_model = RandomForestClassifier()
NB_classifier = NB_model.fit(x_train, y_train)
NB_prediction = NB_classifier.predict(x_test)
from sklearn.metrics import classification_report, confusion_matrix
CM = confusion_matrix(y_test, NB_prediction)
print("confusion matrix:\n", CM)
CR=classification_report(y_test, NB_prediction)
print("performance: \n", CR)
from sklearn.metrics import roc_curve, auc
y_prob = NB_model.predict_proba(x_test)[:,1]
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(false_positive_rate, true_positive_rate)
roc_auc
# Out:
# confusion matrix:
#  [[ 4  1]
#  [ 1 72]]
# performance:
#                precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80         5
#            1       0.99      0.99      0.99        73
#
#     accuracy                           0.97        78
#    macro avg       0.89      0.89      0.89        78
# weighted avg       0.97      0.97      0.97        78
# np.float64(0.9808219178082191)

# %%
plt.figure(figsize=(10,10))
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate,true_positive_rate, color='red',label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],linestyle='--')
plt.axis('tight')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
# Out:
# Text(0.5, 0, 'False Positive Rate')

# %%
from sklearn.tree import DecisionTreeClassifier
NB_model = DecisionTreeClassifier()
NB_classifier = NB_model.fit(x_train, y_train)
NB_prediction = NB_classifier.predict(x_test)
from sklearn.metrics import classification_report, confusion_matrix
CM = confusion_matrix(y_test, NB_prediction)
print("confusion matrix:\n", CM)
CR=classification_report(y_test, NB_prediction)
print("performance: \n", CR)
from sklearn.metrics import roc_curve, auc
y_prob = NB_model.predict_proba(x_test)[:,1]
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(false_positive_rate, true_positive_rate)
roc_auc
# Out:
# confusion matrix:
#  [[ 4  1]
#  [ 4 69]]
# performance:
#                precision    recall  f1-score   support
#
#            0       0.50      0.80      0.62         5
#            1       0.99      0.95      0.97        73
#
#     accuracy                           0.94        78
#    macro avg       0.74      0.87      0.79        78
# weighted avg       0.95      0.94      0.94        78
# np.float64(0.8726027397260274)

# %%
plt.figure(figsize=(10,10))
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate,true_positive_rate, color='red',label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],linestyle='--')
plt.axis('tight')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
# Out:
# Text(0.5, 0, 'False Positive Rate')

# %%
from sklearn.svm import SVC

# %%
NB_model = SVC(probability=True)
NB_classifier = NB_model.fit(x_train, y_train)
NB_prediction = NB_classifier.predict(x_test)
from sklearn.metrics import classification_report, confusion_matrix
CM = confusion_matrix(y_test, NB_prediction)
print("confusion matrix:\n", CM)
CR=classification_report(y_test, NB_prediction)
print("performance: \n", CR)
from sklearn.metrics import roc_curve, auc
y_prob = NB_model.predict_proba(x_test)[:,0]
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(false_positive_rate, true_positive_rate)
roc_auc
# Out:
# confusion matrix:
#  [[ 0  5]
#  [ 0 73]]
# performance:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         5
#            1       0.94      1.00      0.97        73
#
#     accuracy                           0.94        78
#    macro avg       0.47      0.50      0.48        78
# weighted avg       0.88      0.94      0.90        78
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# np.float64(0.03287671232876711)

# %%
plt.figure(figsize=(10,10))
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate,true_positive_rate, color='red',label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],linestyle='--')
plt.axis('tight')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
# Out:
# Text(0.5, 0, 'False Positive Rate')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
model = LogisticRegression(solver='liblinear', random_state=0).fit(x_train, y_train)
NB_prediction = model.predict(x_test)
CM = confusion_matrix(y_test, NB_prediction)
print("confusion matrix:\n", CM)
CR=classification_report(y_test, NB_prediction)
print("performance: \n", CR)
from sklearn.metrics import roc_curve, auc
y_prob = model.predict_proba(x_test)[:,1]
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(false_positive_rate, true_positive_rate)
roc_auc
# Out:
# confusion matrix:
#  [[ 2  3]
#  [ 1 72]]
# performance:
#                precision    recall  f1-score   support
#
#            0       0.67      0.40      0.50         5
#            1       0.96      0.99      0.97        73
#
#     accuracy                           0.95        78
#    macro avg       0.81      0.69      0.74        78
# weighted avg       0.94      0.95      0.94        78
# np.float64(0.7753424657534246)

# %%
plt.figure(figsize=(10,10))
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate,true_positive_rate, color='red',label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],linestyle='--')
plt.axis('tight')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
# Out:
# Text(0.5, 0, 'False Positive Rate')

# %%
plt.figure(figsize=(10,10))
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate,true_positive_rate, color='red',label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],linestyle='--')
plt.axis('tight')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
# Out:
# Text(0.5, 0, 'False Positive Rate')

# %%
svm = SVC(probability=True)
lr = LogisticRegression()
vc = VotingClassifier(estimators=[('lr', lr), ('svm', svm)], voting='soft')
vc.fit(x_train, y_train)
vc_y_pre = vc.predict(x_test)
CR=classification_report(y_test, vc_y_pre)
print("performance: \n", CR)
# Out:
# performance:
#                precision    recall  f1-score   support
#
#            0       0.75      0.60      0.67         5
#            1       0.97      0.99      0.98        73
#
#     accuracy                           0.96        78
#    macro avg       0.86      0.79      0.82        78
# weighted avg       0.96      0.96      0.96        78
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
data.isnull().sum()
# Out:
# GENDER                   0
# AGE                      0
# SMOKING                  0
# YELLOW_FINGERS           0
# ANXIETY                  0
# PEER_PRESSURE            0
# CHRONIC DISEASE          0
# FATIGUE                  0
# ALLERGY                  0
# WHEEZING                 0
# ALCOHOL CONSUMING        0
# COUGHING                 0
# SHORTNESS OF BREATH      0
# SWALLOWING DIFFICULTY    0
# CHEST PAIN               0
# LUNG_CANCER              0
# dtype: int64

# %%
data.keys()
# Out:
# Index(['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
#        'PEER_PRESSURE', 'CHRONIC DISEASE', 'FATIGUE ', 'ALLERGY ', 'WHEEZING',
#        'ALCOHOL CONSUMING', 'COUGHING', 'SHORTNESS OF BREATH',
#        'SWALLOWING DIFFICULTY', 'CHEST PAIN', 'LUNG_CANCER'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# শুধু numeric কলামগুলো বেছে নেওয়া
numeric_data = data.select_dtypes(include=['number'])

# Correlation matrix plot
plt.figure(figsize=(20, 10))
sns.heatmap(numeric_data.corr(), annot=True, cmap="winter")
plt.title("Correlation Heatmap")
plt.show()

# %%
data.describe()
# Out:
#               AGE     SMOKING  YELLOW_FINGERS     ANXIETY  PEER_PRESSURE  \
# count  309.000000  309.000000      309.000000  309.000000     309.000000
# mean    62.673139    1.563107        1.569579    1.498382       1.501618
# std      8.210301    0.496806        0.495938    0.500808       0.500808
# min     21.000000    1.000000        1.000000    1.000000       1.000000
# 25%     57.000000    1.000000        1.000000    1.000000       1.000000
# 50%     62.000000    2.000000        2.000000    1.000000       2.000000
# 75%     69.000000    2.000000        2.000000    2.000000       2.000000
# max     87.000000    2.000000        2.000000    2.000000       2.000000
#
#        CHRONIC DISEASE    FATIGUE     ALLERGY     WHEEZING  ALCOHOL CONSUMING  \
# count       309.000000  309.000000  309.000000  309.000000         309.000000
# mean          1.504854    1.673139    1.556634    1.556634           1.556634
# std           0.500787    0.469827    0.497588    0.497588           0.497588
# min           1.000000    1.000000    1.000000    1.000000           1.000000
# 25%           1.000000    1.000000    1.000000    1.000000           1.000000
# 50%           2.000000    2.000000    2.000000    2.000000           2.000000
# 75%           2.000000    2.000000    2.000000    2.000000           2.000000
# max           2.000000    2.000000    2.000000    2.000000           2.000000
#
#          COUGHING  SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN
# count  309.000000           309.000000             309.000000  309.000000
# mean     1.579288             1.640777               1.469256    1.556634
# std      0.494474             0.480551               0.499863    0.497588
# min      1.000000             1.000000               1.000000    1.000000
# 25%      1.000000             1.000000               1.000000    1.000000
# 50%      2.000000             2.000000               1.000000    2.000000
# 75%      2.000000             2.000000               2.000000    2.000000
# max      2.000000             2.000000               2.000000    2.000000

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(x)
scaled_x = scaler.transform(x)
print(scaled_x)
# Out:
# [[ 0.95257934  0.77185028 -1.13529242 ...  0.74873631  1.06350105
#    0.892475  ]
#  [ 0.95257934  1.38182914  0.88083033 ...  0.74873631  1.06350105
#    0.892475  ]
#  [-1.04978132 -0.44810745 -1.13529242 ...  0.74873631 -0.94029056
#    0.892475  ]
#  ...
#  [ 0.95257934 -0.57010322  0.88083033 ... -1.33558369 -0.94029056
#    0.892475  ]
#  [ 0.95257934  0.52785873  0.88083033 ...  0.74873631 -0.94029056
#    0.892475  ]
#  [ 0.95257934 -0.08212013 -1.13529242 ... -1.33558369  1.06350105
#   -1.12047956]]

# %%
pca = PCA(n_components=8)
pca.fit(scaled_x)
pca_x = pca.transform(scaled_x)
pca_x.shape
# Out:
# (309, 8)

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import GridSearchCV
#Support Vector Machine (SVM)
param_grid = {'C': [0.1, 1, 10, 100, 1000],
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
              'kernel': ['rbf']}

grid = GridSearchCV(SVC(), param_grid, refit = True, verbose = 3)
grid.fit(pca_x, y)
grid.best_params_
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.871 total time=   0.0s
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.871 total time=   0.0s
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.871 total time=   0.0s
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.871 total time=   0.0s
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.885 total time=   0.0s
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.871 total time=   0.0s
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.871 total time=   0.0s
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.871 total time=   0.0s
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.871 total time=   0.0s
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.885 total time=   0.0s
# [CV 1/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.871 total time=   0.0s
# [CV 2/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.871 total time=   0.0s
# [CV 3/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.871 total time=   0.0s
# [CV 4/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.871 total time=   0.0s
# [CV 5/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.885 total time=   0.0s
# [CV 1/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.871 total time=   0.0s
# [CV 2/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.871 total time=   0.0s
# [CV 3/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.871 total time=   0.0s
# [CV 4/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.871 total time=   0.0s
# [CV 5/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.885 total time=   0.0s
# [CV 1/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.871 total time=   0.0s
# [CV 2/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.871 total time=   0.0s
# [CV 3/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.871 total time=   0.0s
# [CV 4/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.871 total time=   0.0s
# [CV 5/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.885 total time=   0.0s
# [CV 1/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.887 total time=   0.0s
# [CV 2/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.855 total time=   0.0s
# [CV 3/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.903 total time=   0.0s
# [CV 4/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.903 total time=   0.0s
# [CV 5/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.902 total time=   0.0s
# [CV 1/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.935 total time=   0.0s
# [CV 2/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.855 total time=   0.0s
# [CV 3/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.935 total time=   0.0s
# [CV 4/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.887 total time=   0.0s
# [CV 5/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.934 total time=   0.0s
# [CV 1/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.871 total time=   0.0s
# [CV 2/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.855 total time=   0.0s
# [CV 3/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.871 total time=   0.0s
# [CV 4/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.855 total time=   0.0s
# [CV 5/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.885 total time=   0.0s
# [CV 1/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.871 total time=   0.0s
# [CV 2/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.871 total time=   0.0s
# [CV 3/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.871 total time=   0.0s
# [CV 4/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.871 total time=   0.0s
# [CV 5/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.885 total time=   0.0s
# [CV 1/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.871 total time=   0.0s
# [CV 2/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.871 total time=   0.0s
# [CV 3/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.871 total time=   0.0s
# [CV 4/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.871 total time=   0.0s
# [CV 5/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.885 total time=   0.0s
# [CV 1/5] END .........C=10, gamma=1, kernel=rbf;, score=0.887 total time=   0.0s
# [CV 2/5] END .........C=10, gamma=1, kernel=rbf;, score=0.871 total time=   0.0s
# [CV 3/5] END .........C=10, gamma=1, kernel=rbf;, score=0.919 total time=   0.0s
# [CV 4/5] END .........C=10, gamma=1, kernel=rbf;, score=0.919 total time=   0.0s
# [CV 5/5] END .........C=10, gamma=1, kernel=rbf;, score=0.902 total time=   0.0s
# [CV 1/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.935 total time=   0.0s
# [CV 2/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.839 total time=   0.0s
# [CV 3/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.919 total time=   0.0s
# [CV 4/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.871 total time=   0.0s
# [CV 5/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.951 total time=   0.0s
# [CV 1/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.919 total time=   0.0s
# [CV 2/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.871 total time=   0.0s
# [CV 3/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 4/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.871 total time=   0.0s
# [CV 5/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.951 total time=   0.0s
# [CV 1/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.871 total time=   0.0s
# [CV 2/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.839 total time=   0.0s
# [CV 3/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.871 total time=   0.0s
# [CV 4/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.839 total time=   0.0s
# [CV 5/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.885 total time=   0.0s
# [CV 1/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.871 total time=   0.0s
# [CV 2/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.871 total time=   0.0s
# [CV 3/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.871 total time=   0.0s
# [CV 4/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.871 total time=   0.0s
# [CV 5/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.885 total time=   0.0s
# [CV 1/5] END ........C=100, gamma=1, kernel=rbf;, score=0.903 total time=   0.0s
# [CV 2/5] END ........C=100, gamma=1, kernel=rbf;, score=0.871 total time=   0.0s
# [CV 3/5] END ........C=100, gamma=1, kernel=rbf;, score=0.919 total time=   0.0s
# [CV 4/5] END ........C=100, gamma=1, kernel=rbf;, score=0.919 total time=   0.0s
# [CV 5/5] END ........C=100, gamma=1, kernel=rbf;, score=0.902 total time=   0.0s
# [CV 1/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.935 total time=   0.0s
# [CV 2/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.839 total time=   0.0s
# [CV 3/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.903 total time=   0.0s
# [CV 4/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.839 total time=   0.0s
# [CV 5/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.934 total time=   0.0s
# [CV 1/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.887 total time=   0.0s
# [CV 2/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.855 total time=   0.0s
# [CV 3/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.952 total time=   0.0s
# [CV 4/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.855 total time=   0.0s
# [CV 5/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.951 total time=   0.0s
# [CV 1/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.903 total time=   0.0s
# [CV 2/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.871 total time=   0.0s
# [CV 3/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 4/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.871 total time=   0.0s
# [CV 5/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.951 total time=   0.0s
# [CV 1/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.871 total time=   0.0s
# [CV 2/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.839 total time=   0.0s
# [CV 3/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.871 total time=   0.0s
# [CV 4/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.839 total time=   0.0s
# [CV 5/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.885 total time=   0.0s
# [CV 1/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.903 total time=   0.0s
# [CV 2/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.871 total time=   0.0s
# [CV 3/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.919 total time=   0.0s
# [CV 4/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.919 total time=   0.0s
# [CV 5/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.902 total time=   0.0s
# [CV 1/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.903 total time=   0.0s
# [CV 2/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.839 total time=   0.0s
# [CV 3/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.903 total time=   0.0s
# [CV 4/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.855 total time=   0.0s
# [CV 5/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.902 total time=   0.0s
# [CV 1/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.919 total time=   0.0s
# [CV 2/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.855 total time=   0.0s
# [CV 3/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.935 total time=   0.0s
# [CV 4/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.855 total time=   0.0s
# [CV 5/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.934 total time=   0.0s
# [CV 1/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.903 total time=   0.0s
# [CV 2/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.871 total time=   0.0s
# [CV 3/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 4/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.855 total time=   0.0s
# [CV 5/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.951 total time=   0.0s
# [CV 1/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.903 total time=   0.0s
# [CV 2/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.855 total time=   0.0s
# [CV 3/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.968 total time=   0.0s
# [CV 4/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.871 total time=   0.0s
# [CV 5/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.951 total time=   0.0s
# {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}

# %%
from sklearn.metrics import accuracy_score
from sklearn.feature_selection import mutual_info_classif
#Support Vector Machine (SVM)
svm = SVC(C= 10, gamma= 0.01, kernel= 'rbf')
svm_y_pre = cross_val_predict(svm, pca_x, y, cv=9)
svm_sc = accuracy_score(y, svm_y_pre) * 100
svm_sc = "{:.2f}".format(svm_sc)
print(svm_sc)
CM = confusion_matrix(y, svm_y_pre)
print("confusion matrix:\n", CM)
CR=classification_report(y, svm_y_pre)
print("performance: \n", CR)
from sklearn.metrics import roc_curve, auc
y_prob = NB_model.predict_proba(x_test)[:,0]
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(false_positive_rate, true_positive_rate)
roc_auc
# Out:
# 92.23
# confusion matrix:
#  [[ 26  13]
#  [ 11 259]]
# performance:
#                precision    recall  f1-score   support
#
#            0       0.70      0.67      0.68        39
#            1       0.95      0.96      0.96       270
#
#     accuracy                           0.92       309
#    macro avg       0.83      0.81      0.82       309
# weighted avg       0.92      0.92      0.92       309
# np.float64(0.03287671232876711)

# %%
plt.figure(figsize=(10,10))
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate,true_positive_rate, color='red',label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],linestyle='--')
plt.axis('tight')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
# Out:
# Text(0.5, 0, 'False Positive Rate')

# %%
from sklearn.metrics import accuracy_score
from sklearn.feature_selection import mutual_info_classif
from sklearn.ensemble import RandomForestClassifier
#Random Forest
rf = RandomForestClassifier(criterion='entropy', random_state = 0)
rf_y_pre = cross_val_predict(rf, pca_x, y, cv=9)
rf_sc = accuracy_score(y, rf_y_pre) * 100
rf_sc = "{:.2f}".format(rf_sc)
print(rf_sc)
CM = confusion_matrix(y, rf_y_pre)
print("confusion matrix:\n", CM)
CR=classification_report(y, rf_y_pre)
print("performance: \n", CR)
from sklearn.metrics import roc_curve, auc
y_prob = NB_model.predict_proba(x_test)[:,1]
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(false_positive_rate, true_positive_rate)
roc_auc
# Out:
# 89.97
# confusion matrix:
#  [[ 18  21]
#  [ 10 260]]
# performance:
#                precision    recall  f1-score   support
#
#            0       0.64      0.46      0.54        39
#            1       0.93      0.96      0.94       270
#
#     accuracy                           0.90       309
#    macro avg       0.78      0.71      0.74       309
# weighted avg       0.89      0.90      0.89       309
# np.float64(0.9671232876712328)

# %%
plt.figure(figsize=(10,10))
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate,true_positive_rate, color='red',label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],linestyle='--')
plt.axis('tight')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
# Out:
# Text(0.5, 0, 'False Positive Rate')

# %%
from sklearn.metrics import accuracy_score
from sklearn.feature_selection import mutual_info_classif
#NB
nb = GaussianNB()
nb_y_pre = cross_val_predict(nb, pca_x, y, cv=9)
nb_sc = accuracy_score(y, nb_y_pre) * 100
nb_sc = "{:.2f}".format(nb_sc)
print(nb_sc)
CM = confusion_matrix(y, nb_y_pre)
print("confusion matrix:\n", CM)
CR=classification_report(y, nb_y_pre)
print("performance: \n", CR)
from sklearn.metrics import roc_curve, auc
y_prob = NB_model.predict_proba(x_test)[:,0]
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(false_positive_rate, true_positive_rate)
roc_auc
# Out:
# 91.59
# confusion matrix:
#  [[ 21  18]
#  [  8 262]]
# performance:
#                precision    recall  f1-score   support
#
#            0       0.72      0.54      0.62        39
#            1       0.94      0.97      0.95       270
#
#     accuracy                           0.92       309
#    macro avg       0.83      0.75      0.79       309
# weighted avg       0.91      0.92      0.91       309
# np.float64(0.03287671232876711)

# %%
plt.figure(figsize=(10,10))
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate,true_positive_rate, color='red',label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],linestyle='--')
plt.axis('tight')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
# Out:
# Text(0.5, 0, 'False Positive Rate')

# %%
from sklearn.metrics import accuracy_score
from sklearn.feature_selection import mutual_info_classif
#D_tree
dt = DecisionTreeClassifier()
dt_y_pre = cross_val_predict(dt, pca_x, y, cv=9)
dt_sc = accuracy_score(y, dt_y_pre) * 100
dt_sc = "{:.2f}".format(dt_sc)
print(dt_sc)
CM = confusion_matrix(y, dt_y_pre)
print("confusion matrix:\n", CM)
CR=classification_report(y, dt_y_pre)
print("performance: \n", CR)
from sklearn.metrics import roc_curve, auc
y_prob = NB_model.predict_proba(x_test)[:,0]
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(false_positive_rate, true_positive_rate)
roc_auc
# Out:
# 89.00
# confusion matrix:
#  [[ 21  18]
#  [ 16 254]]
# performance:
#                precision    recall  f1-score   support
#
#            0       0.57      0.54      0.55        39
#            1       0.93      0.94      0.94       270
#
#     accuracy                           0.89       309
#    macro avg       0.75      0.74      0.74       309
# weighted avg       0.89      0.89      0.89       309
# np.float64(0.03287671232876711)

# %%
plt.figure(figsize=(10,10))
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate,true_positive_rate, color='red',label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],linestyle='--')
plt.axis('tight')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
# Out:
# Text(0.5, 0, 'False Positive Rate')

# %%
from sklearn.metrics import accuracy_score
from sklearn.feature_selection import mutual_info_classif
lr = LogisticRegression()
lr_y_pre = cross_val_predict(lr, pca_x, y, cv=9)
lr_sc = accuracy_score(y, lr_y_pre) * 100
lr_sc = "{:.2f}".format(lr_sc)
print(lr_sc)
CM = confusion_matrix(y, lr_y_pre)
print("confusion matrix:\n", CM)
CR=classification_report(y, lr_y_pre)
print("performance: \n", CR)
from sklearn.metrics import roc_curve, auc
y_prob = NB_model.predict_proba(x_test)[:,0]
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(false_positive_rate, true_positive_rate)
roc_auc
# Out:
# 90.61
# confusion matrix:
#  [[ 21  18]
#  [ 11 259]]
# performance:
#                precision    recall  f1-score   support
#
#            0       0.66      0.54      0.59        39
#            1       0.94      0.96      0.95       270
#
#     accuracy                           0.91       309
#    macro avg       0.80      0.75      0.77       309
# weighted avg       0.90      0.91      0.90       309
# np.float64(0.03287671232876711)

# %%
plt.figure(figsize=(10,10))
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate,true_positive_rate, color='red',label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],linestyle='--')
plt.axis('tight')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
# Out:
# Text(0.5, 0, 'False Positive Rate')

# %%
svm = SVC(C= 10, gamma= 0.01, kernel= 'rbf', probability=True)
lr = LogisticRegression()
vc = VotingClassifier(estimators=[('lr', lr), ('svm', svm)], voting='soft')
vc.fit(scaled_x, y)
# Out:
# VotingClassifier(estimators=[('lr', LogisticRegression()),
#                              ('svm', SVC(C=10, gamma=0.01, probability=True))],
#                  voting='soft')

# %%
vc_y_pre = vc.predict(scaled_x)
CR=classification_report(y, vc_y_pre)
print("performance: \n", CR)
# Out:
# performance:
#                precision    recall  f1-score   support
#
#            0       0.83      0.77      0.80        39
#            1       0.97      0.98      0.97       270
#
#     accuracy                           0.95       309
#    macro avg       0.90      0.87      0.89       309
# weighted avg       0.95      0.95      0.95       309
